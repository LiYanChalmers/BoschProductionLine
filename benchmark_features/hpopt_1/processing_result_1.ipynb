# %%
from bosch_helper import *

# %%
for (dirpath, dirnames, filenames) in os.walk('hpop_test_1_result_1'):
    pass

# %%
file_id = []
for f in filenames:
    if f.split('.')[1]=='pickle':
        file_id.append(int(f.split('.')[0].split('_')[1]))

# %%
file_id
# Out:
# [0, 2, 28, 33, 37, 41, 45, 66, 68, 76, 79, 80, 82, 88, 9, 95, 98]

# %%
param_dict = {}
for f in file_id:
    file_name = 'ht_{}.py'.format(f)
    file_name = os.path.join('hpop_test_1_result_1', file_name)
    with open(file_name, 'r') as py_file:
        lines = py_file.readlines()
        param_dict[f] = lines[30]

# %%
import ast

# %%
param_dict = {k: ast.literal_eval(param_dict[k][8:-1]) for k in param_dict.keys()}

# %%
results = read_pickle('hpop_test_1_result_1/ht_0.pickle')

# %%
cv_mean = {}
cv_std = {}
for f in file_id:
    results = read_pickle('hpop_test_1_result_1/ht_0.pickle')
    cv_mean[f] = results['results_cv']['test'].mean(axis=1)
    cv_std[f] = results['results_cv']['test'].std(axis=1)

# %%
cv_mean = pd.DataFrame(cv_mean)
cv_std = pd.DataFrame(cv_std)

# %%
for f in file_id:
    plt.plot(cv_mean.loc[40:, f])

# %%
cv_mean
# Out:
#                  0         2         28        33        37        41  \
# iteration
# 0          0.293437  0.293437  0.293437  0.293437  0.293437  0.293437
# 1          0.334630  0.334630  0.334630  0.334630  0.334630  0.334630
# 2          0.354043  0.354043  0.354043  0.354043  0.354043  0.354043
# 3          0.363378  0.363378  0.363378  0.363378  0.363378  0.363378
# 4          0.371794  0.371794  0.371794  0.371794  0.371794  0.371794
# 5          0.382729  0.382729  0.382729  0.382729  0.382729  0.382729
# 6          0.388222  0.388222  0.388222  0.388222  0.388222  0.388222
# 7          0.395484  0.395484  0.395484  0.395484  0.395484  0.395484
# 8          0.400520  0.400520  0.400520  0.400520  0.400520  0.400520
# 9          0.404834  0.404834  0.404834  0.404834  0.404834  0.404834
# 10         0.409920  0.409920  0.409920  0.409920  0.409920  0.409920
# 11         0.413618  0.413618  0.413618  0.413618  0.413618  0.413618
# ...

# %%
cv_std
# Out:
#                  0         2         28        33        37        41  \
# iteration
# 0          0.015740  0.015740  0.015740  0.015740  0.015740  0.015740
# 1          0.017622  0.017622  0.017622  0.017622  0.017622  0.017622
# 2          0.018475  0.018475  0.018475  0.018475  0.018475  0.018475
# 3          0.017639  0.017639  0.017639  0.017639  0.017639  0.017639
# 4          0.015016  0.015016  0.015016  0.015016  0.015016  0.015016
# 5          0.013473  0.013473  0.013473  0.013473  0.013473  0.013473
# 6          0.015486  0.015486  0.015486  0.015486  0.015486  0.015486
# 7          0.012604  0.012604  0.012604  0.012604  0.012604  0.012604
# 8          0.011488  0.011488  0.011488  0.011488  0.011488  0.011488
# 9          0.011389  0.011389  0.011389  0.011389  0.011389  0.011389
# 10         0.011397  0.011397  0.011397  0.011397  0.011397  0.011397
# 11         0.011834  0.011834  0.011834  0.011834  0.011834  0.011834
# ...

# %%
param_dict = pd.DataFrame(param_dict)

# %%
param_dict
# Out:
#                                0                2                28  \
# alpha                           0              0.1              0.1
# base_score                 0.0058           0.0058           0.0058
# booster                    gbtree           gbtree           gbtree
# colsample_bytree             0.65              0.6              0.5
# eta                         0.025            0.025            0.025
# lambda                        3.5              3.5              4.5
# max_depth                      13               16               13
# min_child_weight              5.5                5              5.5
# nthread                        20               20               20
# objective         binary:logistic  binary:logistic  binary:logistic
# silent                          1                1                1
# subsample                    0.95             0.95             0.85
#
#                                33               37               41  \
# ...
