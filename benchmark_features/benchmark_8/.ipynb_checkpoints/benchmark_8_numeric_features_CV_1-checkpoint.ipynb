# %% [markdown]
# ## Benchmark for measuring performance of engineered features and models
#
# Prepare data for later analysis

# %%
import sys
sys.path.insert(0, '../../bosch_helper')
from bosch_helper import *

from sklearn.preprocessing import LabelEncoder

# %matplotlib inline

# %% [markdown]
# ### Load train and test data

# %%
# important numeric features are imported
important_features = pd.read_csv('../benchmark_1/important_numeric_features.csv', index_col=0, header=None)
important_features = list(important_features.values.ravel())
important_features.extend(['Id', 'Response'])

# %%
x_train_numeric = pd.read_csv('../../data/train_numeric.csv.zip', index_col=0, usecols=important_features, dtype=np.float32)

y_train = x_train_numeric.Response
x_train_numeric.drop(['Response'], axis=1, inplace=True)

# %%
date_train = pd.read_csv('../benchmark_2/train_station_flow.csv.gz', index_col=0, header=None)

# %%
x_train = x_train_numeric.join(date_train)

columns = list(x_train.columns)
columns[-1] = 'station_flow'
x_train.columns = columns

# %%
x_test_numeric = pd.read_csv('../../data/test_numeric.csv.zip', index_col=0, usecols=important_features[:-1], dtype=np.float32)

date_test = pd.read_csv('../benchmark_2/test_station_flow.csv.gz', index_col=0, header=None)

x_test = x_test_numeric.join(date_test)
x_test.columns = columns

# %%
x_train.index = x_train.index.astype(np.int64)
x_test.index = x_test.index.astype(np.int64)

# %%
del x_train_numeric, x_test_numeric
gc.collect()
# Out:
# 60

# %% [markdown]
# ### Load benchmark_3 features

# %%
start_chunk = pd.read_csv('../benchmark_3/start_chunk.csv.gz', index_col=0)

start_chunk_train = start_chunk.loc[start_chunk.Response!=-1].drop(['Response'], axis=1)
start_chunk_test = start_chunk.loc[start_chunk.Response==-1].drop(['Response'], axis=1)

# %%
x_train = x_train.join(start_chunk_train, on='Id')
x_test = x_test.join(start_chunk_test, on='Id')

gc.collect()
# Out:
# 35

# %% [markdown]
# ### Load benchmark_4 features

# %%
n = pd.read_csv('../benchmark_4/benchmark_4_neighbors.csv.gz', index_col=0)

neighbor_train = n.loc[n.Response!=-1]
neighbor_train.drop(['Response'], axis=1, inplace=True)

neighbor_test = n.loc[n.Response==-1]
neighbor_test.drop(['Response'], axis=1, inplace=True)

print(neighbor_test.shape, neighbor_train.shape)

x_train = x_train.join(neighbor_train, on='Id')
x_test = x_test.join(neighbor_test, on='Id')

gc.collect()
# Out:
# (1183748, 14) (1183747, 14)
# 28

# %% [markdown]
# ### Add neighbor numeric features

# %%
# Date + station flow data will be added to x
x = pd.concat([x_train, x_test], keys=['train', 'test'])
x.sort_index(axis=0, level='Id', inplace=True)

# Add the neighbor records
x = x.join(x.iloc[:, :150].shift(), rsuffix='_previous')
x = x.join(x.iloc[:, :150].shift(-1), rsuffix='_next')

# %% [markdown]
# ### Load benchmark_7 features

# %%
time_features = pd.read_hdf('../benchmark_7/time_features_diff.hdf', 'time_features')
time_features.drop(['time_start', 'time_end', 'time_duration', 'Response'], axis=1, inplace=True)

# %%
# Find MeanTimeDiff and discard them
# time_features.columns.tolist()[-40:]

# Join to x
x = x.join(time_features.iloc[:, :-40])

# %% [markdown]
# ### Load benchmark_8 features

# %%
# hash of rows and counts of duplications
hash_numeric = pd.read_hdf('benchmark_8_numeric_features_2.hdf', 'hash_numeric')

x = x.join(hash_numeric)

# %%
# zscore per week
x_zscore_per_week = pd.read_hdf('benchmark_8_numeric_features_2.hdf', 'zscore_per_week')

# %%
# select important features
tmp = important_features.copy()
tmp.remove('Response')
tmp.remove('Id')

# %%
x_zscore_per_week_if = x_zscore_per_week[tmp]

# %%
x = x.join(x_zscore_per_week_if, rsuffix='_zscore')

# %%
del x_zscore_per_week, x_zscore_per_week_if
gc.collect()
# Out:
# 21

# %%
x_count_encoded = pd.read_hdf('benchmark_8_numeric_features_2.hdf', 'count_encoded')

# %%
tmp = ['count_'+k for k in tmp]

# %%
x_count_encoded_if = x_count_encoded[tmp]

# %%
x_count_encoded_if.shape
# Out:
# (2367495, 149)

# %%
x = x.join(x_count_encoded_if)

# %%
del x_count_encoded, x_count_encoded_if
gc.collect()
# Out:
# 123

# %%
x_train = x.loc['train']
x_test = x.loc['test']

# %%
del x
gc.collect()
# Out:
# Exception ignored in: <function DMatrix.__del__ at 0x7f3bd4348510>
# Traceback (most recent call last):
#   File "/c3se/NOBACKUP/users/lyaa/conda_dir/miniconda/envs/kaggle/lib/python3.7/site-packages/xgboost/core.py", line 366, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# 28632

# %% [markdown]
# ### CV score based on stratified KFold with repeated models

# %%
# CV
# specify parameters 
# 'booster':'gbtree'
params = {'max_depth':14, 'eta':0.03, 'silent':1, 'objective':'binary:logistic', 'nthread':16,
         'lambda':4, 'subsample':0.9, 'min_child_weight':5, 'booster':'gbtree', 'alpha':0,
         'base_score':0.0058, 'colsample_bytree':0.6}

# 'booster':'dart'
# params = {'max_depth':14, 'eta':0.03, 'silent':1, 'objective':'binary:logistic', 'nthread':20,
#         'lambda':4, 'subsample':0.9, 'min_child_weight':5, 'booster':'dart', 'alpha':0,
#         'base_score':0.0058, 'nthread':20, 'colsample_bytree':0.6, 
#         'sample_type':'uniform', 'normalize_type':'tree', 'rate_drop':0.1, 'skip_drop':0.2, 'one_drop':True}

cv_results, clfs, running_time = cross_val_predict_skf_rm_xgb(params, x_train, y_train, 
                                                              num_boost_round=100, n_splits=5, 
                                                              n_repeats=3, random_state=70864, 
                                                              verbose_eval=True)

results = {'clfs': clfs, 'cv_results': cv_results, 'running_time': running_time}
save_pickle(results, 'results_benchmark_8_cv_1.pickle')
# Out:
# [0]	train-error:0.005811	test-error:0.005812	train-MCC:0.276114	test-MCC:0.265946
# [1]	train-error:0.005811	test-error:0.005812	train-MCC:0.340044	test-MCC:0.338623
# [2]	train-error:0.005811	test-error:0.005812	train-MCC:0.346387	test-MCC:0.353783
# [3]	train-error:0.005811	test-error:0.005812	train-MCC:0.371335	test-MCC:0.382685
# [4]	train-error:0.005811	test-error:0.005812	train-MCC:0.380802	test-MCC:0.389524
# [5]	train-error:0.005811	test-error:0.005812	train-MCC:0.385607	test-MCC:0.389064
# [6]	train-error:0.005811	test-error:0.005812	train-MCC:0.396484	test-MCC:0.393424
# [7]	train-error:0.005811	test-error:0.005812	train-MCC:0.403017	test-MCC:0.394805
# [8]	train-error:0.005811	test-error:0.005812	train-MCC:0.415024	test-MCC:0.404272
# [9]	train-error:0.005811	test-error:0.005812	train-MCC:0.42884	test-MCC:0.414574
# [10]	train-error:0.005811	test-error:0.005812	train-MCC:0.432537	test-MCC:0.414227
# [11]	train-error:0.005811	test-error:0.005812	train-MCC:0.438036	test-MCC:0.422941
# [12]	train-error:0.00581	test-error:0.005812	train-MCC:0.443804	test-MCC:0.424457
# [13]	train-error:0.005809	test-error:0.005808	train-MCC:0.449294	test-MCC:0.426522
# [14]	train-error:0.005808	test-error:0.005808	train-MCC:0.451429	test-MCC:0.425578
# [15]	train-error:0.005808	test-error:0.005808	train-MCC:0.457269	test-MCC:0.430695
# [16]	train-error:0.005806	test-error:0.005808	train-MCC:0.460464	test-MCC:0.432908
# [17]	train-error:0.005806	test-error:0.005808	train-MCC:0.464071	test-MCC:0.435452
# [18]	train-error:0.005806	test-error:0.005808	train-MCC:0.470135	test-MCC:0.435421
# [19]	train-error:0.005792	test-error:0.005808	train-MCC:0.473059	test-MCC:0.434758
# [20]	train-error:0.005759	test-error:0.005774	train-MCC:0.476194	test-MCC:0.440178
# [21]	train-error:0.005689	test-error:0.005711	train-MCC:0.478201	test-MCC:0.438334
# [22]	train-error:0.005585	test-error:0.005609	train-MCC:0.48002	test-MCC:0.440982
# [23]	train-error:0.005476	test-error:0.005533	train-MCC:0.481115	test-MCC:0.442744
# [24]	train-error:0.005379	test-error:0.005428	train-MCC:0.483508	test-MCC:0.441796
# [25]	train-error:0.005316	test-error:0.005356	train-MCC:0.486106	test-MCC:0.444405
# [26]	train-error:0.005258	test-error:0.005301	train-MCC:0.488566	test-MCC:0.444361
# [27]	train-error:0.005211	test-error:0.005254	train-MCC:0.489719	test-MCC:0.445775
# [28]	train-error:0.005182	test-error:0.005242	train-MCC:0.493874	test-MCC:0.447052
# [29]	train-error:0.005155	test-error:0.005204	train-MCC:0.496137	test-MCC:0.449451
# [30]	train-error:0.00513	test-error:0.005174	train-MCC:0.499643	test-MCC:0.450118
# [31]	train-error:0.005111	test-error:0.005166	train-MCC:0.500791	test-MCC:0.451479
# [32]	train-error:0.005094	test-error:0.005157	train-MCC:0.501855	test-MCC:0.452287
# [33]	train-error:0.005075	test-error:0.005145	train-MCC:0.50443	test-MCC:0.454697
# [34]	train-error:0.005065	test-error:0.00514	train-MCC:0.506891	test-MCC:0.453897
# [35]	train-error:0.005045	test-error:0.005124	train-MCC:0.509499	test-MCC:0.45467
# [36]	train-error:0.005032	test-error:0.005119	train-MCC:0.510661	test-MCC:0.457454
# [37]	train-error:0.005005	test-error:0.005094	train-MCC:0.512769	test-MCC:0.455924
# [38]	train-error:0.004991	test-error:0.005077	train-MCC:0.514968	test-MCC:0.454931
# [39]	train-error:0.004966	test-error:0.005073	train-MCC:0.516356	test-MCC:0.457235
# [40]	train-error:0.004943	test-error:0.005052	train-MCC:0.516234	test-MCC:0.458279
# [41]	train-error:0.004928	test-error:0.005022	train-MCC:0.518243	test-MCC:0.457235
# [42]	train-error:0.004917	test-error:0.00501	train-MCC:0.520811	test-MCC:0.455509
# [43]	train-error:0.004894	test-error:0.004997	train-MCC:0.521436	test-MCC:0.455952
# [44]	train-error:0.004874	test-error:0.004971	train-MCC:0.523453	test-MCC:0.456181
# [45]	train-error:0.004862	test-error:0.004955	train-MCC:0.524458	test-MCC:0.455671
# [46]	train-error:0.00484	test-error:0.00495	train-MCC:0.525594	test-MCC:0.454981
# [47]	train-error:0.004821	test-error:0.00495	train-MCC:0.526767	test-MCC:0.45648
# [48]	train-error:0.004791	test-error:0.004929	train-MCC:0.528293	test-MCC:0.459387
# [49]	train-error:0.004774	test-error:0.004925	train-MCC:0.530446	test-MCC:0.458996
# [50]	train-error:0.00476	test-error:0.004912	train-MCC:0.53252	test-MCC:0.460352
# [51]	train-error:0.00475	test-error:0.004917	train-MCC:0.535016	test-MCC:0.459984
# [52]	train-error:0.004724	test-error:0.004895	train-MCC:0.535668	test-MCC:0.459013
# [53]	train-error:0.004704	test-error:0.004895	train-MCC:0.539456	test-MCC:0.45919
# [54]	train-error:0.004701	test-error:0.004891	train-MCC:0.544108	test-MCC:0.458223
# [55]	train-error:0.004684	test-error:0.004874	train-MCC:0.545777	test-MCC:0.458242
# [56]	train-error:0.004671	test-error:0.004866	train-MCC:0.54917	test-MCC:0.45933
# [57]	train-error:0.004664	test-error:0.004857	train-MCC:0.553131	test-MCC:0.459418
# [58]	train-error:0.004649	test-error:0.004849	train-MCC:0.553767	test-MCC:0.459256
# [59]	train-error:0.004642	test-error:0.004841	train-MCC:0.555447	test-MCC:0.460693
# [60]	train-error:0.004627	test-error:0.004824	train-MCC:0.55611	test-MCC:0.460352
# [61]	train-error:0.004624	test-error:0.004815	train-MCC:0.5579	test-MCC:0.460243
# [62]	train-error:0.004617	test-error:0.004807	train-MCC:0.559212	test-MCC:0.461229
# [63]	train-error:0.004608	test-error:0.004794	train-MCC:0.560577	test-MCC:0.45933
# [64]	train-error:0.004602	test-error:0.00479	train-MCC:0.564498	test-MCC:0.459801
# [65]	train-error:0.004597	test-error:0.004765	train-MCC:0.566769	test-MCC:0.45994
# [66]	train-error:0.004585	test-error:0.00476	train-MCC:0.568966	test-MCC:0.459776
# [67]	train-error:0.00458	test-error:0.004752	train-MCC:0.573404	test-MCC:0.459486
# [68]	train-error:0.004574	test-error:0.004756	train-MCC:0.575285	test-MCC:0.459242
# [69]	train-error:0.004562	test-error:0.004752	train-MCC:0.578848	test-MCC:0.459195
# [70]	train-error:0.004551	test-error:0.004748	train-MCC:0.580511	test-MCC:0.460039
# [71]	train-error:0.004538	test-error:0.004752	train-MCC:0.582971	test-MCC:0.460127
# [72]	train-error:0.004533	test-error:0.004752	train-MCC:0.585288	test-MCC:0.460344
# [73]	train-error:0.004529	test-error:0.004739	train-MCC:0.588029	test-MCC:0.461015
# [74]	train-error:0.00453	test-error:0.004731	train-MCC:0.589901	test-MCC:0.460388
# [75]	train-error:0.004524	test-error:0.004727	train-MCC:0.591594	test-MCC:0.461015
# [76]	train-error:0.00452	test-error:0.004722	train-MCC:0.593642	test-MCC:0.461226
# [77]	train-error:0.004509	test-error:0.004714	train-MCC:0.596353	test-MCC:0.461779
# [78]	train-error:0.004507	test-error:0.00471	train-MCC:0.597697	test-MCC:0.460462
# [79]	train-error:0.004503	test-error:0.004705	train-MCC:0.599177	test-MCC:0.462202
# [80]	train-error:0.00449	test-error:0.004714	train-MCC:0.602384	test-MCC:0.463176
# [81]	train-error:0.00448	test-error:0.004697	train-MCC:0.604253	test-MCC:0.464273
# [82]	train-error:0.004478	test-error:0.004701	train-MCC:0.605782	test-MCC:0.463065
# [83]	train-error:0.004466	test-error:0.004701	train-MCC:0.609696	test-MCC:0.462847
# [84]	train-error:0.004459	test-error:0.004688	train-MCC:0.611667	test-MCC:0.46345
# [85]	train-error:0.004456	test-error:0.004684	train-MCC:0.613956	test-MCC:0.464211
# [86]	train-error:0.00445	test-error:0.004684	train-MCC:0.614747	test-MCC:0.462415
# [87]	train-error:0.004445	test-error:0.00468	train-MCC:0.617791	test-MCC:0.46187
# [88]	train-error:0.004441	test-error:0.004676	train-MCC:0.620665	test-MCC:0.462631
# [89]	train-error:0.004434	test-error:0.004676	train-MCC:0.624641	test-MCC:0.462306
# [90]	train-error:0.004429	test-error:0.004672	train-MCC:0.62762	test-MCC:0.462306
# [91]	train-error:0.00442	test-error:0.004672	train-MCC:0.629203	test-MCC:0.462526
# [92]	train-error:0.004416	test-error:0.004667	train-MCC:0.632237	test-MCC:0.46085
# [93]	train-error:0.004414	test-error:0.004667	train-MCC:0.635247	test-MCC:0.461226
# [94]	train-error:0.004406	test-error:0.004655	train-MCC:0.637134	test-MCC:0.46168
# [95]	train-error:0.0044	test-error:0.004655	train-MCC:0.638389	test-MCC:0.461121
# [96]	train-error:0.004396	test-error:0.004659	train-MCC:0.641427	test-MCC:0.460751
# [97]	train-error:0.004391	test-error:0.004659	train-MCC:0.641929	test-MCC:0.461132
# [98]	train-error:0.00438	test-error:0.004663	train-MCC:0.645539	test-MCC:0.462039
# [99]	train-error:0.004378	test-error:0.004659	train-MCC:0.646228	test-MCC:0.462686
# Repeat 0, split 0, test MCC = 0.463, running time = 13.610 min
# [0]	train-error:0.005811	test-error:0.005812	train-MCC:0.270624	test-MCC:0.269936
# [1]	train-error:0.005811	test-error:0.005812	train-MCC:0.316855	test-MCC:0.318785
# [2]	train-error:0.005811	test-error:0.005812	train-MCC:0.341523	test-MCC:0.353729
# [3]	train-error:0.005811	test-error:0.005812	train-MCC:0.350434	test-MCC:0.355952
# [4]	train-error:0.005811	test-error:0.005812	train-MCC:0.363715	test-MCC:0.362193
# [5]	train-error:0.005811	test-error:0.005812	train-MCC:0.376989	test-MCC:0.369106
# [6]	train-error:0.005811	test-error:0.005812	train-MCC:0.390496	test-MCC:0.379317
# [7]	train-error:0.005811	test-error:0.005812	train-MCC:0.398553	test-MCC:0.387452
# [8]	train-error:0.005811	test-error:0.005812	train-MCC:0.408672	test-MCC:0.38681
# [9]	train-error:0.005811	test-error:0.005812	train-MCC:0.420724	test-MCC:0.388132
# [10]	train-error:0.005811	test-error:0.005812	train-MCC:0.424462	test-MCC:0.39065
# [11]	train-error:0.005811	test-error:0.005812	train-MCC:0.430274	test-MCC:0.393924
# [12]	train-error:0.005811	test-error:0.005812	train-MCC:0.436056	test-MCC:0.397122
# [13]	train-error:0.005809	test-error:0.005812	train-MCC:0.441429	test-MCC:0.399277
# [14]	train-error:0.005807	test-error:0.005812	train-MCC:0.447668	test-MCC:0.401111
# [15]	train-error:0.005807	test-error:0.005812	train-MCC:0.453252	test-MCC:0.406577
# [16]	train-error:0.005805	test-error:0.005812	train-MCC:0.459131	test-MCC:0.41161
# [17]	train-error:0.005804	test-error:0.005812	train-MCC:0.463035	test-MCC:0.411987
# [18]	train-error:0.005791	test-error:0.005791	train-MCC:0.467555	test-MCC:0.41337
# [19]	train-error:0.005743	test-error:0.005736	train-MCC:0.468879	test-MCC:0.416299
# [20]	train-error:0.005678	test-error:0.005711	train-MCC:0.471308	test-MCC:0.419468
# [21]	train-error:0.005605	test-error:0.005647	train-MCC:0.474077	test-MCC:0.420908
# [22]	train-error:0.005509	test-error:0.005588	train-MCC:0.476697	test-MCC:0.423678
# [23]	train-error:0.005437	test-error:0.005542	train-MCC:0.477799	test-MCC:0.423897
# [24]	train-error:0.005381	test-error:0.005504	train-MCC:0.480867	test-MCC:0.426601
# [25]	train-error:0.00535	test-error:0.005474	train-MCC:0.484336	test-MCC:0.428345
# [26]	train-error:0.005316	test-error:0.005415	train-MCC:0.48676	test-MCC:0.430254
# [27]	train-error:0.005286	test-error:0.005398	train-MCC:0.48882	test-MCC:0.431311
# [28]	train-error:0.00526	test-error:0.005364	train-MCC:0.490143	test-MCC:0.433044
# [29]	train-error:0.005238	test-error:0.005335	train-MCC:0.491766	test-MCC:0.434957
# [30]	train-error:0.005211	test-error:0.005305	train-MCC:0.493145	test-MCC:0.437275
# [31]	train-error:0.005191	test-error:0.005293	train-MCC:0.494203	test-MCC:0.438815
# [32]	train-error:0.005166	test-error:0.005271	train-MCC:0.496381	test-MCC:0.440233
# [33]	train-error:0.005132	test-error:0.00525	train-MCC:0.498434	test-MCC:0.441519
# [34]	train-error:0.005099	test-error:0.00525	train-MCC:0.499656	test-MCC:0.440047
# [35]	train-error:0.005076	test-error:0.005229	train-MCC:0.501101	test-MCC:0.441845
# [36]	train-error:0.005042	test-error:0.005178	train-MCC:0.502924	test-MCC:0.442072
# [37]	train-error:0.005021	test-error:0.005149	train-MCC:0.503194	test-MCC:0.442226
# [38]	train-error:0.004989	test-error:0.005119	train-MCC:0.504277	test-MCC:0.442541
# [39]	train-error:0.00497	test-error:0.005119	train-MCC:0.506598	test-MCC:0.441648
# [40]	train-error:0.004941	test-error:0.005094	train-MCC:0.507484	test-MCC:0.441399
# [41]	train-error:0.004917	test-error:0.005073	train-MCC:0.509261	test-MCC:0.440001
# [42]	train-error:0.004902	test-error:0.005056	train-MCC:0.509572	test-MCC:0.441901
# [43]	train-error:0.004878	test-error:0.005026	train-MCC:0.510068	test-MCC:0.443804
# [44]	train-error:0.00486	test-error:0.005005	train-MCC:0.512361	test-MCC:0.445218
# [45]	train-error:0.004836	test-error:0.004993	train-MCC:0.514592	test-MCC:0.444403
# [46]	train-error:0.004827	test-error:0.004993	train-MCC:0.516321	test-MCC:0.445218
# [47]	train-error:0.004808	test-error:0.004993	train-MCC:0.516745	test-MCC:0.443998
# [48]	train-error:0.004795	test-error:0.004988	train-MCC:0.517464	test-MCC:0.445887
# [49]	train-error:0.004782	test-error:0.004959	train-MCC:0.519254	test-MCC:0.443632
# [50]	train-error:0.004768	test-error:0.004942	train-MCC:0.520334	test-MCC:0.443135
# [51]	train-error:0.004754	test-error:0.004933	train-MCC:0.525108	test-MCC:0.444497
# [52]	train-error:0.00474	test-error:0.004921	train-MCC:0.526442	test-MCC:0.444797
# [53]	train-error:0.004728	test-error:0.004912	train-MCC:0.528218	test-MCC:0.44496
# [54]	train-error:0.004713	test-error:0.004904	train-MCC:0.531853	test-MCC:0.447688
# [55]	train-error:0.004701	test-error:0.0049	train-MCC:0.532072	test-MCC:0.444883
# [56]	train-error:0.004687	test-error:0.0049	train-MCC:0.53397	test-MCC:0.445786
# [57]	train-error:0.004682	test-error:0.0049	train-MCC:0.53648	test-MCC:0.444215
# [58]	train-error:0.004668	test-error:0.004908	train-MCC:0.538241	test-MCC:0.443901
# [59]	train-error:0.004657	test-error:0.0049	train-MCC:0.541332	test-MCC:0.443362
# [60]	train-error:0.004649	test-error:0.004895	train-MCC:0.543205	test-MCC:0.445235
# [61]	train-error:0.004637	test-error:0.004895	train-MCC:0.545576	test-MCC:0.445155
# [62]	train-error:0.004627	test-error:0.004887	train-MCC:0.545586	test-MCC:0.443706
# [63]	train-error:0.004614	test-error:0.00487	train-MCC:0.547546	test-MCC:0.444646
# [64]	train-error:0.004612	test-error:0.00487	train-MCC:0.549435	test-MCC:0.444124
# [65]	train-error:0.00461	test-error:0.004862	train-MCC:0.550589	test-MCC:0.444755
# [66]	train-error:0.004596	test-error:0.004857	train-MCC:0.552388	test-MCC:0.445288
# [67]	train-error:0.004589	test-error:0.004845	train-MCC:0.555098	test-MCC:0.44668
# [68]	train-error:0.004577	test-error:0.004845	train-MCC:0.557698	test-MCC:0.44636
# [69]	train-error:0.004565	test-error:0.004845	train-MCC:0.558668	test-MCC:0.44807
# [70]	train-error:0.004553	test-error:0.004836	train-MCC:0.561993	test-MCC:0.447223
# [71]	train-error:0.004546	test-error:0.004841	train-MCC:0.566117	test-MCC:0.446469
# [72]	train-error:0.004533	test-error:0.004836	train-MCC:0.567734	test-MCC:0.446893
# [73]	train-error:0.004524	test-error:0.004832	train-MCC:0.568834	test-MCC:0.4477
# [74]	train-error:0.004516	test-error:0.004836	train-MCC:0.570657	test-MCC:0.448438
# [75]	train-error:0.004508	test-error:0.004832	train-MCC:0.573175	test-MCC:0.447296
# [76]	train-error:0.004504	test-error:0.004819	train-MCC:0.574598	test-MCC:0.448175
# [77]	train-error:0.004494	test-error:0.004819	train-MCC:0.576988	test-MCC:0.449657
# [78]	train-error:0.004488	test-error:0.004819	train-MCC:0.578156	test-MCC:0.44941
# [79]	train-error:0.004484	test-error:0.004815	train-MCC:0.579546	test-MCC:0.448771
# [80]	train-error:0.004483	test-error:0.004811	train-MCC:0.58256	test-MCC:0.44941
# [81]	train-error:0.004475	test-error:0.004803	train-MCC:0.583537	test-MCC:0.449083
# [82]	train-error:0.00447	test-error:0.00479	train-MCC:0.585103	test-MCC:0.449822
# [83]	train-error:0.004467	test-error:0.00479	train-MCC:0.586753	test-MCC:0.449738
# [84]	train-error:0.004465	test-error:0.00479	train-MCC:0.587967	test-MCC:0.448418
# [85]	train-error:0.004463	test-error:0.004794	train-MCC:0.591166	test-MCC:0.449622
# [86]	train-error:0.004459	test-error:0.00479	train-MCC:0.591612	test-MCC:0.44892
# [87]	train-error:0.004458	test-error:0.004777	train-MCC:0.593329	test-MCC:0.449128
# [88]	train-error:0.004452	test-error:0.004773	train-MCC:0.595985	test-MCC:0.450198
# [89]	train-error:0.004449	test-error:0.004769	train-MCC:0.596853	test-MCC:0.450518
# [90]	train-error:0.004447	test-error:0.00476	train-MCC:0.599076	test-MCC:0.450518
# [91]	train-error:0.004438	test-error:0.004756	train-MCC:0.600948	test-MCC:0.45116
# [92]	train-error:0.00443	test-error:0.004756	train-MCC:0.605135	test-MCC:0.450621
# [93]	train-error:0.004421	test-error:0.004765	train-MCC:0.606935	test-MCC:0.450322
# [94]	train-error:0.004419	test-error:0.004765	train-MCC:0.608455	test-MCC:0.449744
# [95]	train-error:0.004417	test-error:0.004765	train-MCC:0.611317	test-MCC:0.449679
# [96]	train-error:0.004411	test-error:0.004765	train-MCC:0.613323	test-MCC:0.449777
# [97]	train-error:0.004408	test-error:0.00476	train-MCC:0.616375	test-MCC:0.450992
# [98]	train-error:0.004403	test-error:0.00476	train-MCC:0.617963	test-MCC:0.449744
# [99]	train-error:0.004397	test-error:0.00476	train-MCC:0.619839	test-MCC:0.44926
# Repeat 0, split 1, test MCC = 0.449, running time = 14.162 min
# [0]	train-error:0.005811	test-error:0.005812	train-MCC:0.286845	test-MCC:0.281136
# [1]	train-error:0.005811	test-error:0.005812	train-MCC:0.316076	test-MCC:0.308784
# [2]	train-error:0.005811	test-error:0.005812	train-MCC:0.333271	test-MCC:0.325892
# [3]	train-error:0.005811	test-error:0.005812	train-MCC:0.352129	test-MCC:0.34269
# [4]	train-error:0.005811	test-error:0.005812	train-MCC:0.365251	test-MCC:0.345594
# [5]	train-error:0.005811	test-error:0.005812	train-MCC:0.378896	test-MCC:0.359648
# [6]	train-error:0.005811	test-error:0.005812	train-MCC:0.381073	test-MCC:0.368465
# [7]	train-error:0.005811	test-error:0.005812	train-MCC:0.387799	test-MCC:0.370513
# [8]	train-error:0.005811	test-error:0.005812	train-MCC:0.395806	test-MCC:0.380384
# [9]	train-error:0.005811	test-error:0.005812	train-MCC:0.406147	test-MCC:0.393626
# [10]	train-error:0.005811	test-error:0.005812	train-MCC:0.410234	test-MCC:0.394836
# [11]	train-error:0.005811	test-error:0.005812	train-MCC:0.41957	test-MCC:0.404712
# [12]	train-error:0.005811	test-error:0.005812	train-MCC:0.42739	test-MCC:0.408643
# [13]	train-error:0.005811	test-error:0.005812	train-MCC:0.434932	test-MCC:0.412571
# [14]	train-error:0.005811	test-error:0.005812	train-MCC:0.441179	test-MCC:0.418264
# [15]	train-error:0.005811	test-error:0.005812	train-MCC:0.446412	test-MCC:0.421068
# [16]	train-error:0.005811	test-error:0.005808	train-MCC:0.452468	test-MCC:0.424992
# [17]	train-error:0.005811	test-error:0.005804	train-MCC:0.455698	test-MCC:0.425179
# [18]	train-error:0.00581	test-error:0.005799	train-MCC:0.45842	test-MCC:0.42812
# [19]	train-error:0.005808	test-error:0.005791	train-MCC:0.4635	test-MCC:0.431977
# [20]	train-error:0.005785	test-error:0.005766	train-MCC:0.464125	test-MCC:0.434773
# [21]	train-error:0.005713	test-error:0.005706	train-MCC:0.46687	test-MCC:0.433
# [22]	train-error:0.005652	test-error:0.005652	train-MCC:0.469663	test-MCC:0.433397
# [23]	train-error:0.005586	test-error:0.005571	train-MCC:0.472085	test-MCC:0.434453
# [24]	train-error:0.005534	test-error:0.005529	train-MCC:0.474108	test-MCC:0.438343
# [25]	train-error:0.005497	test-error:0.005491	train-MCC:0.477764	test-MCC:0.436732
# [26]	train-error:0.005442	test-error:0.005457	train-MCC:0.480027	test-MCC:0.438787
# [27]	train-error:0.005389	test-error:0.005402	train-MCC:0.483927	test-MCC:0.440283
# [28]	train-error:0.005323	test-error:0.005352	train-MCC:0.485314	test-MCC:0.442487
# [29]	train-error:0.005261	test-error:0.005314	train-MCC:0.488886	test-MCC:0.444733
# [30]	train-error:0.005204	test-error:0.005259	train-MCC:0.488668	test-MCC:0.445706
# [31]	train-error:0.005152	test-error:0.005238	train-MCC:0.489617	test-MCC:0.447662
# [32]	train-error:0.005105	test-error:0.005221	train-MCC:0.491155	test-MCC:0.44669
# [33]	train-error:0.00507	test-error:0.005212	train-MCC:0.493211	test-MCC:0.447108
# [34]	train-error:0.005046	test-error:0.005183	train-MCC:0.495581	test-MCC:0.449472
# [35]	train-error:0.005015	test-error:0.005166	train-MCC:0.496634	test-MCC:0.447866
# [36]	train-error:0.004987	test-error:0.005153	train-MCC:0.49735	test-MCC:0.448785
# [37]	train-error:0.00495	test-error:0.005132	train-MCC:0.499281	test-MCC:0.449279
# [38]	train-error:0.00493	test-error:0.005107	train-MCC:0.499908	test-MCC:0.448907
# [39]	train-error:0.00491	test-error:0.005077	train-MCC:0.502218	test-MCC:0.450542
# [40]	train-error:0.004891	test-error:0.005048	train-MCC:0.503874	test-MCC:0.450464
# [41]	train-error:0.004878	test-error:0.005043	train-MCC:0.506555	test-MCC:0.451783
# [42]	train-error:0.00486	test-error:0.005048	train-MCC:0.509242	test-MCC:0.452486
# [43]	train-error:0.004842	test-error:0.005014	train-MCC:0.511232	test-MCC:0.451713
# [44]	train-error:0.004821	test-error:0.004988	train-MCC:0.514853	test-MCC:0.45219
# [45]	train-error:0.004809	test-error:0.004984	train-MCC:0.51834	test-MCC:0.452251
# [46]	train-error:0.004795	test-error:0.00498	train-MCC:0.520371	test-MCC:0.451476
# [47]	train-error:0.004777	test-error:0.004971	train-MCC:0.525201	test-MCC:0.453128
# [48]	train-error:0.004766	test-error:0.004955	train-MCC:0.528154	test-MCC:0.451868
# [49]	train-error:0.004749	test-error:0.004942	train-MCC:0.530773	test-MCC:0.452974
# [50]	train-error:0.004735	test-error:0.004938	train-MCC:0.532134	test-MCC:0.453229
# [51]	train-error:0.004717	test-error:0.004929	train-MCC:0.534724	test-MCC:0.453648
# [52]	train-error:0.004705	test-error:0.004904	train-MCC:0.536239	test-MCC:0.453495
# [53]	train-error:0.004694	test-error:0.004879	train-MCC:0.540247	test-MCC:0.454968
# [54]	train-error:0.004679	test-error:0.004866	train-MCC:0.542039	test-MCC:0.455078
# [55]	train-error:0.004666	test-error:0.004862	train-MCC:0.542774	test-MCC:0.454164
# [56]	train-error:0.004648	test-error:0.004849	train-MCC:0.544073	test-MCC:0.454007
# [57]	train-error:0.004642	test-error:0.004845	train-MCC:0.546442	test-MCC:0.455352
# [58]	train-error:0.004631	test-error:0.004845	train-MCC:0.548647	test-MCC:0.454575
# [59]	train-error:0.004618	test-error:0.004832	train-MCC:0.550044	test-MCC:0.455193
# [60]	train-error:0.00461	test-error:0.004811	train-MCC:0.555214	test-MCC:0.457059
# [61]	train-error:0.004604	test-error:0.004807	train-MCC:0.556144	test-MCC:0.458716
# [62]	train-error:0.004601	test-error:0.004807	train-MCC:0.559388	test-MCC:0.456957
# [63]	train-error:0.004593	test-error:0.004803	train-MCC:0.561519	test-MCC:0.456752
# [64]	train-error:0.004588	test-error:0.004794	train-MCC:0.562902	test-MCC:0.458595
# [65]	train-error:0.004579	test-error:0.004786	train-MCC:0.564543	test-MCC:0.457878
# [66]	train-error:0.004566	test-error:0.004773	train-MCC:0.567163	test-MCC:0.457827
# [67]	train-error:0.004564	test-error:0.004777	train-MCC:0.568575	test-MCC:0.457177
# [68]	train-error:0.004551	test-error:0.004777	train-MCC:0.573451	test-MCC:0.459063
# [69]	train-error:0.004543	test-error:0.004765	train-MCC:0.574589	test-MCC:0.458294
# [70]	train-error:0.004536	test-error:0.00476	train-MCC:0.577514	test-MCC:0.45651
# [71]	train-error:0.004529	test-error:0.004765	train-MCC:0.58066	test-MCC:0.45651
# [72]	train-error:0.004528	test-error:0.004765	train-MCC:0.582291	test-MCC:0.456622
# [73]	train-error:0.004514	test-error:0.004769	train-MCC:0.586116	test-MCC:0.456333
# [74]	train-error:0.004506	test-error:0.004765	train-MCC:0.588323	test-MCC:0.456333
# [75]	train-error:0.004493	test-error:0.004752	train-MCC:0.591416	test-MCC:0.454968
# [76]	train-error:0.004488	test-error:0.004752	train-MCC:0.593418	test-MCC:0.455222
# [77]	train-error:0.004483	test-error:0.004748	train-MCC:0.595124	test-MCC:0.454698
# [78]	train-error:0.004478	test-error:0.004748	train-MCC:0.59639	test-MCC:0.455205
# [79]	train-error:0.004474	test-error:0.004739	train-MCC:0.600185	test-MCC:0.455352
# [80]	train-error:0.004472	test-error:0.004735	train-MCC:0.60219	test-MCC:0.454942
# [81]	train-error:0.004465	test-error:0.004731	train-MCC:0.602385	test-MCC:0.45486
# [82]	train-error:0.004458	test-error:0.004727	train-MCC:0.604965	test-MCC:0.455419
# [83]	train-error:0.004448	test-error:0.004718	train-MCC:0.606227	test-MCC:0.455922
# [84]	train-error:0.004442	test-error:0.004722	train-MCC:0.608792	test-MCC:0.45585
# [85]	train-error:0.004431	test-error:0.004718	train-MCC:0.60972	test-MCC:0.455646
# [86]	train-error:0.004423	test-error:0.004714	train-MCC:0.613724	test-MCC:0.456189
# [87]	train-error:0.004419	test-error:0.00471	train-MCC:0.616474	test-MCC:0.456189
# [88]	train-error:0.004416	test-error:0.00471	train-MCC:0.61801	test-MCC:0.455963
# [89]	train-error:0.004406	test-error:0.004705	train-MCC:0.62122	test-MCC:0.455193
# [90]	train-error:0.004401	test-error:0.004697	train-MCC:0.623313	test-MCC:0.454648
# [91]	train-error:0.004395	test-error:0.004697	train-MCC:0.627519	test-MCC:0.455646
# [92]	train-error:0.004386	test-error:0.004697	train-MCC:0.629482	test-MCC:0.455337
# [93]	train-error:0.004386	test-error:0.004701	train-MCC:0.630456	test-MCC:0.455106
# [94]	train-error:0.00438	test-error:0.004701	train-MCC:0.632002	test-MCC:0.455963
# [95]	train-error:0.00438	test-error:0.004697	train-MCC:0.634374	test-MCC:0.455193
# [96]	train-error:0.004367	test-error:0.004693	train-MCC:0.637409	test-MCC:0.453891
# [97]	train-error:0.004361	test-error:0.004684	train-MCC:0.640846	test-MCC:0.455434
# [98]	train-error:0.004356	test-error:0.004684	train-MCC:0.644014	test-MCC:0.45443
# [99]	train-error:0.004353	test-error:0.004684	train-MCC:0.646117	test-MCC:0.454942
# Repeat 0, split 2, test MCC = 0.455, running time = 13.537 min
# [0]	train-error:0.005811	test-error:0.005812	train-MCC:0.279158	test-MCC:0.284718
# [1]	train-error:0.005811	test-error:0.005812	train-MCC:0.330301	test-MCC:0.336053
# [2]	train-error:0.005811	test-error:0.005812	train-MCC:0.366782	test-MCC:0.364582
# [3]	train-error:0.005811	test-error:0.005812	train-MCC:0.372606	test-MCC:0.369124
# [4]	train-error:0.005811	test-error:0.005812	train-MCC:0.379202	test-MCC:0.368469
# [5]	train-error:0.005811	test-error:0.005812	train-MCC:0.384079	test-MCC:0.372892
# [6]	train-error:0.005811	test-error:0.005812	train-MCC:0.390397	test-MCC:0.380461
# [7]	train-error:0.005811	test-error:0.005812	train-MCC:0.396981	test-MCC:0.382918
# [8]	train-error:0.005811	test-error:0.005812	train-MCC:0.404613	test-MCC:0.386428
# [9]	train-error:0.005811	test-error:0.005812	train-MCC:0.411929	test-MCC:0.388385
# [10]	train-error:0.005811	test-error:0.005812	train-MCC:0.42066	test-MCC:0.389874
# [11]	train-error:0.005811	test-error:0.005812	train-MCC:0.425733	test-MCC:0.392114
# [12]	train-error:0.005811	test-error:0.005812	train-MCC:0.432309	test-MCC:0.394456
# [13]	train-error:0.005811	test-error:0.005812	train-MCC:0.434414	test-MCC:0.3952
# [14]	train-error:0.005811	test-error:0.005812	train-MCC:0.437809	test-MCC:0.397095
# [15]	train-error:0.005811	test-error:0.005808	train-MCC:0.441867	test-MCC:0.396642
# [16]	train-error:0.005809	test-error:0.005808	train-MCC:0.449625	test-MCC:0.398044
# [17]	train-error:0.005809	test-error:0.005808	train-MCC:0.454849	test-MCC:0.400579
# [18]	train-error:0.005806	test-error:0.005808	train-MCC:0.460195	test-MCC:0.402685
# [19]	train-error:0.005798	test-error:0.005808	train-MCC:0.463712	test-MCC:0.403115
# [20]	train-error:0.005751	test-error:0.005782	train-MCC:0.470438	test-MCC:0.40373
# [21]	train-error:0.00569	test-error:0.005702	train-MCC:0.47635	test-MCC:0.406441
# [22]	train-error:0.005618	test-error:0.00563	train-MCC:0.479858	test-MCC:0.409653
# [23]	train-error:0.005528	test-error:0.005563	train-MCC:0.481719	test-MCC:0.412545
# [24]	train-error:0.005448	test-error:0.005495	train-MCC:0.4827	test-MCC:0.413028
# [25]	train-error:0.005348	test-error:0.005411	train-MCC:0.48611	test-MCC:0.417242
# [26]	train-error:0.005287	test-error:0.005335	train-MCC:0.487955	test-MCC:0.418178
# [27]	train-error:0.005218	test-error:0.005259	train-MCC:0.489125	test-MCC:0.418488
# [28]	train-error:0.005178	test-error:0.005221	train-MCC:0.491942	test-MCC:0.420858
# [29]	train-error:0.00515	test-error:0.005174	train-MCC:0.494951	test-MCC:0.421511
# [30]	train-error:0.005138	test-error:0.005162	train-MCC:0.498161	test-MCC:0.422232
# [31]	train-error:0.005123	test-error:0.005136	train-MCC:0.499964	test-MCC:0.424856
# [32]	train-error:0.005103	test-error:0.005111	train-MCC:0.502959	test-MCC:0.425238
# [33]	train-error:0.005083	test-error:0.005086	train-MCC:0.504363	test-MCC:0.425433
# [34]	train-error:0.005061	test-error:0.005069	train-MCC:0.505553	test-MCC:0.425506
# [35]	train-error:0.005032	test-error:0.005035	train-MCC:0.506923	test-MCC:0.426764
# [36]	train-error:0.004989	test-error:0.004993	train-MCC:0.506998	test-MCC:0.427509
# [37]	train-error:0.004973	test-error:0.004972	train-MCC:0.508487	test-MCC:0.432179
# [38]	train-error:0.004952	test-error:0.004967	train-MCC:0.511786	test-MCC:0.430069
# [39]	train-error:0.004932	test-error:0.004955	train-MCC:0.511611	test-MCC:0.428804
# [40]	train-error:0.004911	test-error:0.004942	train-MCC:0.513771	test-MCC:0.431996
# [41]	train-error:0.004899	test-error:0.004938	train-MCC:0.51702	test-MCC:0.431113
# [42]	train-error:0.004875	test-error:0.004942	train-MCC:0.519004	test-MCC:0.431791
# [43]	train-error:0.00486	test-error:0.004933	train-MCC:0.520566	test-MCC:0.430909
# [44]	train-error:0.004836	test-error:0.004917	train-MCC:0.522304	test-MCC:0.431336
# [45]	train-error:0.004816	test-error:0.004921	train-MCC:0.524361	test-MCC:0.432685
# [46]	train-error:0.004805	test-error:0.004904	train-MCC:0.525489	test-MCC:0.43184
# [47]	train-error:0.004791	test-error:0.0049	train-MCC:0.528251	test-MCC:0.432941
# [48]	train-error:0.004784	test-error:0.004895	train-MCC:0.529729	test-MCC:0.435723
# [49]	train-error:0.004779	test-error:0.004891	train-MCC:0.531134	test-MCC:0.43281
# [50]	train-error:0.004775	test-error:0.004891	train-MCC:0.534742	test-MCC:0.436163
# [51]	train-error:0.004765	test-error:0.004874	train-MCC:0.536192	test-MCC:0.436163
# [52]	train-error:0.004747	test-error:0.004883	train-MCC:0.536959	test-MCC:0.436474
# [53]	train-error:0.00474	test-error:0.004883	train-MCC:0.540759	test-MCC:0.438382
# [54]	train-error:0.004731	test-error:0.004874	train-MCC:0.541651	test-MCC:0.438206
# [55]	train-error:0.004717	test-error:0.004874	train-MCC:0.543625	test-MCC:0.438982
# [56]	train-error:0.004705	test-error:0.004874	train-MCC:0.545012	test-MCC:0.438037
# [57]	train-error:0.004699	test-error:0.004874	train-MCC:0.548023	test-MCC:0.438682
# [58]	train-error:0.004685	test-error:0.004874	train-MCC:0.550804	test-MCC:0.440232
# [59]	train-error:0.004675	test-error:0.004879	train-MCC:0.554039	test-MCC:0.44178
# [60]	train-error:0.004671	test-error:0.004874	train-MCC:0.556036	test-MCC:0.441018
# [61]	train-error:0.004659	test-error:0.004874	train-MCC:0.557912	test-MCC:0.441972
# [62]	train-error:0.00465	test-error:0.004874	train-MCC:0.559802	test-MCC:0.441778
# [63]	train-error:0.004644	test-error:0.00487	train-MCC:0.560593	test-MCC:0.441972
# [64]	train-error:0.004636	test-error:0.00487	train-MCC:0.562683	test-MCC:0.442097
# [65]	train-error:0.004618	test-error:0.004862	train-MCC:0.563746	test-MCC:0.443616
# [66]	train-error:0.00461	test-error:0.004866	train-MCC:0.565387	test-MCC:0.443599
# [67]	train-error:0.004606	test-error:0.00487	train-MCC:0.567062	test-MCC:0.443599
# [68]	train-error:0.004595	test-error:0.004866	train-MCC:0.567601	test-MCC:0.443687
# [69]	train-error:0.004588	test-error:0.004866	train-MCC:0.570253	test-MCC:0.444168
# [70]	train-error:0.004573	test-error:0.004857	train-MCC:0.572994	test-MCC:0.443398
# [71]	train-error:0.004565	test-error:0.004857	train-MCC:0.575173	test-MCC:0.444206
# [72]	train-error:0.004562	test-error:0.004857	train-MCC:0.577141	test-MCC:0.445141
# [73]	train-error:0.004554	test-error:0.004849	train-MCC:0.578483	test-MCC:0.445141
# [74]	train-error:0.004546	test-error:0.004853	train-MCC:0.580947	test-MCC:0.447214
# [75]	train-error:0.00454	test-error:0.004845	train-MCC:0.582674	test-MCC:0.446696
# [76]	train-error:0.004534	test-error:0.004836	train-MCC:0.585233	test-MCC:0.446574
# [77]	train-error:0.004526	test-error:0.004828	train-MCC:0.587203	test-MCC:0.446887
# [78]	train-error:0.004517	test-error:0.004819	train-MCC:0.5902	test-MCC:0.446197
# [79]	train-error:0.004516	test-error:0.004815	train-MCC:0.591542	test-MCC:0.445689
# [80]	train-error:0.004508	test-error:0.004803	train-MCC:0.594995	test-MCC:0.446679
# [81]	train-error:0.004505	test-error:0.004803	train-MCC:0.596344	test-MCC:0.447339
# [82]	train-error:0.004495	test-error:0.004798	train-MCC:0.599091	test-MCC:0.448569
# [83]	train-error:0.004489	test-error:0.004798	train-MCC:0.601677	test-MCC:0.449953
# [84]	train-error:0.004482	test-error:0.004798	train-MCC:0.603001	test-MCC:0.44898
# [85]	train-error:0.004483	test-error:0.004794	train-MCC:0.607559	test-MCC:0.44898
# [86]	train-error:0.004476	test-error:0.004786	train-MCC:0.608276	test-MCC:0.448214
# [87]	train-error:0.004473	test-error:0.004786	train-MCC:0.609624	test-MCC:0.447052
# [88]	train-error:0.004467	test-error:0.004777	train-MCC:0.613305	test-MCC:0.447247
# [89]	train-error:0.004459	test-error:0.004777	train-MCC:0.614807	test-MCC:0.448103
# [90]	train-error:0.004457	test-error:0.004781	train-MCC:0.61784	test-MCC:0.447505
# [91]	train-error:0.004446	test-error:0.004773	train-MCC:0.618845	test-MCC:0.44773
# [92]	train-error:0.004439	test-error:0.004773	train-MCC:0.621292	test-MCC:0.449465
# [93]	train-error:0.004438	test-error:0.004773	train-MCC:0.622984	test-MCC:0.449953
# [94]	train-error:0.004431	test-error:0.004769	train-MCC:0.624662	test-MCC:0.449953
# [95]	train-error:0.004427	test-error:0.00476	train-MCC:0.627238	test-MCC:0.449895
# [96]	train-error:0.004421	test-error:0.004756	train-MCC:0.62967	test-MCC:0.449895
# [97]	train-error:0.004419	test-error:0.004756	train-MCC:0.63159	test-MCC:0.449895
# [98]	train-error:0.004418	test-error:0.004752	train-MCC:0.632569	test-MCC:0.449895
# [99]	train-error:0.004409	test-error:0.004748	train-MCC:0.63545	test-MCC:0.449541
# Repeat 0, split 3, test MCC = 0.450, running time = 13.532 min
# [0]	train-error:0.005812	test-error:0.005808	train-MCC:0.277024	test-MCC:0.272333
# [1]	train-error:0.005812	test-error:0.005808	train-MCC:0.347857	test-MCC:0.330106
# [2]	train-error:0.005812	test-error:0.005808	train-MCC:0.375342	test-MCC:0.362449
# [3]	train-error:0.005812	test-error:0.005808	train-MCC:0.381737	test-MCC:0.369143
# [4]	train-error:0.005812	test-error:0.005808	train-MCC:0.384589	test-MCC:0.371033
# [5]	train-error:0.005812	test-error:0.005808	train-MCC:0.38618	test-MCC:0.371082
# [6]	train-error:0.005812	test-error:0.005808	train-MCC:0.393076	test-MCC:0.372958
# [7]	train-error:0.005812	test-error:0.005808	train-MCC:0.401139	test-MCC:0.374536
# [8]	train-error:0.005812	test-error:0.005808	train-MCC:0.410042	test-MCC:0.381935
# [9]	train-error:0.005812	test-error:0.005808	train-MCC:0.417995	test-MCC:0.388957
# [10]	train-error:0.005812	test-error:0.005808	train-MCC:0.426889	test-MCC:0.400648
# [11]	train-error:0.005812	test-error:0.005808	train-MCC:0.430659	test-MCC:0.39969
# [12]	train-error:0.005811	test-error:0.005808	train-MCC:0.435295	test-MCC:0.406915
# [13]	train-error:0.005811	test-error:0.005808	train-MCC:0.443738	test-MCC:0.410064
# [14]	train-error:0.005809	test-error:0.005808	train-MCC:0.445291	test-MCC:0.411915
# [15]	train-error:0.005808	test-error:0.005808	train-MCC:0.45199	test-MCC:0.41378
# [16]	train-error:0.005806	test-error:0.005808	train-MCC:0.454966	test-MCC:0.415686
# [17]	train-error:0.005805	test-error:0.005808	train-MCC:0.461063	test-MCC:0.425369
# [18]	train-error:0.005785	test-error:0.005778	train-MCC:0.466534	test-MCC:0.424833
# [19]	train-error:0.005712	test-error:0.005711	train-MCC:0.469509	test-MCC:0.42646
# [20]	train-error:0.005636	test-error:0.005618	train-MCC:0.472963	test-MCC:0.424819
# [21]	train-error:0.00558	test-error:0.00558	train-MCC:0.475796	test-MCC:0.425647
# [22]	train-error:0.00552	test-error:0.005542	train-MCC:0.478184	test-MCC:0.430503
# [23]	train-error:0.005461	test-error:0.005504	train-MCC:0.480521	test-MCC:0.42889
# [24]	train-error:0.005405	test-error:0.005462	train-MCC:0.481506	test-MCC:0.429442
# [25]	train-error:0.005316	test-error:0.005419	train-MCC:0.483793	test-MCC:0.429968
# [26]	train-error:0.005271	test-error:0.005364	train-MCC:0.486274	test-MCC:0.430276
# [27]	train-error:0.005235	test-error:0.005314	train-MCC:0.486506	test-MCC:0.429657
# [28]	train-error:0.0052	test-error:0.00528	train-MCC:0.490175	test-MCC:0.431406
# [29]	train-error:0.005174	test-error:0.005259	train-MCC:0.492124	test-MCC:0.429918
# [30]	train-error:0.005159	test-error:0.005225	train-MCC:0.493475	test-MCC:0.430229
# [31]	train-error:0.005151	test-error:0.005204	train-MCC:0.494898	test-MCC:0.4308
# [32]	train-error:0.005134	test-error:0.0052	train-MCC:0.496101	test-MCC:0.432162
# [33]	train-error:0.005115	test-error:0.005183	train-MCC:0.497108	test-MCC:0.435393
# [34]	train-error:0.005106	test-error:0.005162	train-MCC:0.498661	test-MCC:0.435005
# [35]	train-error:0.005086	test-error:0.005153	train-MCC:0.500318	test-MCC:0.436663
# [36]	train-error:0.00506	test-error:0.005145	train-MCC:0.502926	test-MCC:0.438494
# [37]	train-error:0.005038	test-error:0.005124	train-MCC:0.504297	test-MCC:0.438034
# [38]	train-error:0.005016	test-error:0.005124	train-MCC:0.505757	test-MCC:0.439014
# [39]	train-error:0.005	test-error:0.005102	train-MCC:0.506915	test-MCC:0.440075
# [40]	train-error:0.004978	test-error:0.005086	train-MCC:0.507502	test-MCC:0.441652
# [41]	train-error:0.004961	test-error:0.005081	train-MCC:0.510463	test-MCC:0.441958
# [42]	train-error:0.004936	test-error:0.005052	train-MCC:0.512291	test-MCC:0.44166
# [43]	train-error:0.004909	test-error:0.005026	train-MCC:0.514023	test-MCC:0.442726
# [44]	train-error:0.004898	test-error:0.005001	train-MCC:0.515127	test-MCC:0.442198
# [45]	train-error:0.004872	test-error:0.004993	train-MCC:0.51546	test-MCC:0.442177
# [46]	train-error:0.004848	test-error:0.004993	train-MCC:0.516077	test-MCC:0.442697
# [47]	train-error:0.004834	test-error:0.004997	train-MCC:0.517253	test-MCC:0.443044
# [48]	train-error:0.004815	test-error:0.004984	train-MCC:0.519899	test-MCC:0.443827
# [49]	train-error:0.004794	test-error:0.004976	train-MCC:0.522743	test-MCC:0.4454
# [50]	train-error:0.004773	test-error:0.004942	train-MCC:0.522878	test-MCC:0.444319
# [51]	train-error:0.004752	test-error:0.004925	train-MCC:0.523453	test-MCC:0.444525
# [52]	train-error:0.004733	test-error:0.004891	train-MCC:0.524214	test-MCC:0.443735
# [53]	train-error:0.004715	test-error:0.004879	train-MCC:0.525706	test-MCC:0.446001
# [54]	train-error:0.004697	test-error:0.004866	train-MCC:0.526347	test-MCC:0.446281
# [55]	train-error:0.004685	test-error:0.004857	train-MCC:0.528031	test-MCC:0.446001
# [56]	train-error:0.004676	test-error:0.004853	train-MCC:0.52861	test-MCC:0.445938
# [57]	train-error:0.004665	test-error:0.004841	train-MCC:0.530953	test-MCC:0.445318
# [58]	train-error:0.004663	test-error:0.004845	train-MCC:0.533501	test-MCC:0.446184
# [59]	train-error:0.004654	test-error:0.004819	train-MCC:0.535148	test-MCC:0.447706
# [60]	train-error:0.004647	test-error:0.004819	train-MCC:0.536147	test-MCC:0.447756
# [61]	train-error:0.004633	test-error:0.004807	train-MCC:0.53729	test-MCC:0.447706
# [62]	train-error:0.004623	test-error:0.004811	train-MCC:0.538586	test-MCC:0.447402
# [63]	train-error:0.004614	test-error:0.004798	train-MCC:0.542056	test-MCC:0.44791
# [64]	train-error:0.004602	test-error:0.004803	train-MCC:0.542827	test-MCC:0.448418
# [65]	train-error:0.004601	test-error:0.004794	train-MCC:0.545794	test-MCC:0.448708
# [66]	train-error:0.004591	test-error:0.00479	train-MCC:0.547068	test-MCC:0.447937
# [67]	train-error:0.004583	test-error:0.004777	train-MCC:0.548524	test-MCC:0.448441
# [68]	train-error:0.004577	test-error:0.004773	train-MCC:0.5496	test-MCC:0.448748
# [69]	train-error:0.004567	test-error:0.004765	train-MCC:0.551327	test-MCC:0.449192
# [70]	train-error:0.004558	test-error:0.00476	train-MCC:0.553827	test-MCC:0.448947
# [71]	train-error:0.004552	test-error:0.004739	train-MCC:0.55706	test-MCC:0.448928
# [72]	train-error:0.004549	test-error:0.004739	train-MCC:0.5587	test-MCC:0.448191
# [73]	train-error:0.004547	test-error:0.004739	train-MCC:0.561304	test-MCC:0.45024
# [74]	train-error:0.004543	test-error:0.004739	train-MCC:0.563347	test-MCC:0.448941
# [75]	train-error:0.004546	test-error:0.004735	train-MCC:0.566687	test-MCC:0.449425
# [76]	train-error:0.004543	test-error:0.004735	train-MCC:0.56824	test-MCC:0.449425
# [77]	train-error:0.004536	test-error:0.004731	train-MCC:0.569444	test-MCC:0.449909
# [78]	train-error:0.004528	test-error:0.004718	train-MCC:0.572748	test-MCC:0.448586
# [79]	train-error:0.004525	test-error:0.004722	train-MCC:0.574536	test-MCC:0.449217
# [80]	train-error:0.004521	test-error:0.004722	train-MCC:0.577413	test-MCC:0.448746
# [81]	train-error:0.00452	test-error:0.004718	train-MCC:0.578613	test-MCC:0.448746
# [82]	train-error:0.004514	test-error:0.00471	train-MCC:0.580755	test-MCC:0.4488
# [83]	train-error:0.004509	test-error:0.004705	train-MCC:0.581989	test-MCC:0.448941
# [84]	train-error:0.004504	test-error:0.004705	train-MCC:0.584346	test-MCC:0.449988
# [85]	train-error:0.004499	test-error:0.00471	train-MCC:0.584605	test-MCC:0.449988
# [86]	train-error:0.004491	test-error:0.004714	train-MCC:0.586929	test-MCC:0.450395
# [87]	train-error:0.004488	test-error:0.00471	train-MCC:0.588122	test-MCC:0.450395
# [88]	train-error:0.004484	test-error:0.004705	train-MCC:0.59146	test-MCC:0.449988
# [89]	train-error:0.00448	test-error:0.004705	train-MCC:0.592911	test-MCC:0.450284
# [90]	train-error:0.004477	test-error:0.004714	train-MCC:0.594472	test-MCC:0.449478
# [91]	train-error:0.004475	test-error:0.004705	train-MCC:0.595414	test-MCC:0.450284
# [92]	train-error:0.004468	test-error:0.00471	train-MCC:0.598131	test-MCC:0.448708
# [93]	train-error:0.004465	test-error:0.004714	train-MCC:0.601349	test-MCC:0.448128
# [94]	train-error:0.00446	test-error:0.004718	train-MCC:0.605395	test-MCC:0.448054
# [95]	train-error:0.004456	test-error:0.004718	train-MCC:0.605992	test-MCC:0.448482
# [96]	train-error:0.004453	test-error:0.004722	train-MCC:0.607722	test-MCC:0.44907
# [97]	train-error:0.004444	test-error:0.004718	train-MCC:0.6091	test-MCC:0.44907
# [98]	train-error:0.00444	test-error:0.004718	train-MCC:0.609692	test-MCC:0.449828
# [99]	train-error:0.004434	test-error:0.004714	train-MCC:0.610761	test-MCC:0.448902
# Repeat 0, split 4, test MCC = 0.449, running time = 13.510 min
# [0]	train-error:0.005811	test-error:0.005812	train-MCC:0.314443	test-MCC:0.311095
# [1]	train-error:0.005811	test-error:0.005812	train-MCC:0.32891	test-MCC:0.331962
# [2]	train-error:0.005811	test-error:0.005812	train-MCC:0.363724	test-MCC:0.376077
# [3]	train-error:0.005811	test-error:0.005812	train-MCC:0.372709	test-MCC:0.378207
# [4]	train-error:0.005811	test-error:0.005812	train-MCC:0.39181	test-MCC:0.391262
# [5]	train-error:0.005811	test-error:0.005812	train-MCC:0.392766	test-MCC:0.391515
# [6]	train-error:0.005811	test-error:0.005812	train-MCC:0.404887	test-MCC:0.397784
# [7]	train-error:0.005811	test-error:0.005812	train-MCC:0.412303	test-MCC:0.402954
# [8]	train-error:0.005811	test-error:0.005812	train-MCC:0.41984	test-MCC:0.405854
# [9]	train-error:0.005811	test-error:0.005812	train-MCC:0.42283	test-MCC:0.408231
# [10]	train-error:0.005811	test-error:0.005812	train-MCC:0.427781	test-MCC:0.413596
# [11]	train-error:0.005811	test-error:0.005812	train-MCC:0.427938	test-MCC:0.415816
# [12]	train-error:0.005811	test-error:0.005812	train-MCC:0.432851	test-MCC:0.416361
# [13]	train-error:0.005811	test-error:0.005812	train-MCC:0.434485	test-MCC:0.421946
# [14]	train-error:0.005811	test-error:0.005812	train-MCC:0.436863	test-MCC:0.421693
# [15]	train-error:0.005811	test-error:0.005812	train-MCC:0.438992	test-MCC:0.420021
# [16]	train-error:0.00581	test-error:0.005808	train-MCC:0.445372	test-MCC:0.424116
# [17]	train-error:0.00581	test-error:0.005808	train-MCC:0.452559	test-MCC:0.424663
# [18]	train-error:0.005808	test-error:0.005795	train-MCC:0.456306	test-MCC:0.423575
# [19]	train-error:0.005798	test-error:0.005787	train-MCC:0.462771	test-MCC:0.425798
# [20]	train-error:0.005785	test-error:0.005774	train-MCC:0.465938	test-MCC:0.427459
# [21]	train-error:0.005756	test-error:0.005757	train-MCC:0.47132	test-MCC:0.429102
# [22]	train-error:0.005713	test-error:0.005702	train-MCC:0.476605	test-MCC:0.431807
# [23]	train-error:0.005654	test-error:0.00566	train-MCC:0.480032	test-MCC:0.432516
# [24]	train-error:0.005589	test-error:0.005626	train-MCC:0.480627	test-MCC:0.433475
# [25]	train-error:0.005528	test-error:0.005571	train-MCC:0.481794	test-MCC:0.433459
# [26]	train-error:0.005442	test-error:0.005499	train-MCC:0.486611	test-MCC:0.43491
# [27]	train-error:0.005367	test-error:0.005407	train-MCC:0.491487	test-MCC:0.435351
# [28]	train-error:0.005308	test-error:0.005343	train-MCC:0.494761	test-MCC:0.436446
# [29]	train-error:0.005242	test-error:0.005254	train-MCC:0.497646	test-MCC:0.438493
# [30]	train-error:0.005194	test-error:0.005229	train-MCC:0.501425	test-MCC:0.438258
# [31]	train-error:0.005147	test-error:0.005191	train-MCC:0.503613	test-MCC:0.440959
# [32]	train-error:0.005106	test-error:0.005153	train-MCC:0.505167	test-MCC:0.442035
# [33]	train-error:0.005076	test-error:0.005132	train-MCC:0.507292	test-MCC:0.440561
# [34]	train-error:0.005042	test-error:0.00509	train-MCC:0.511729	test-MCC:0.44325
# [35]	train-error:0.005008	test-error:0.005064	train-MCC:0.512934	test-MCC:0.44278
# [36]	train-error:0.004989	test-error:0.005064	train-MCC:0.515596	test-MCC:0.442052
# [37]	train-error:0.004962	test-error:0.005052	train-MCC:0.517054	test-MCC:0.443141
# [38]	train-error:0.004946	test-error:0.005052	train-MCC:0.520394	test-MCC:0.446972
# [39]	train-error:0.004931	test-error:0.005035	train-MCC:0.522774	test-MCC:0.448518
# [40]	train-error:0.004921	test-error:0.005005	train-MCC:0.526121	test-MCC:0.448764
# [41]	train-error:0.004904	test-error:0.005001	train-MCC:0.527134	test-MCC:0.449551
# [42]	train-error:0.00489	test-error:0.004993	train-MCC:0.52949	test-MCC:0.449538
# [43]	train-error:0.004872	test-error:0.004988	train-MCC:0.531457	test-MCC:0.450564
# [44]	train-error:0.004864	test-error:0.004971	train-MCC:0.532873	test-MCC:0.45287
# [45]	train-error:0.004835	test-error:0.004971	train-MCC:0.535681	test-MCC:0.452614
# [46]	train-error:0.004824	test-error:0.004955	train-MCC:0.53661	test-MCC:0.451419
# [47]	train-error:0.004819	test-error:0.00495	train-MCC:0.539048	test-MCC:0.453202
# [48]	train-error:0.004808	test-error:0.004933	train-MCC:0.540769	test-MCC:0.452118
# [49]	train-error:0.004799	test-error:0.004925	train-MCC:0.541391	test-MCC:0.451535
# [50]	train-error:0.004789	test-error:0.004929	train-MCC:0.544606	test-MCC:0.450643
# [51]	train-error:0.004774	test-error:0.004904	train-MCC:0.545193	test-MCC:0.451177
# [52]	train-error:0.004763	test-error:0.0049	train-MCC:0.545846	test-MCC:0.450774
# [53]	train-error:0.004751	test-error:0.004883	train-MCC:0.548309	test-MCC:0.452789
# [54]	train-error:0.004737	test-error:0.004874	train-MCC:0.549501	test-MCC:0.453548
# [55]	train-error:0.004727	test-error:0.004862	train-MCC:0.551961	test-MCC:0.453619
# [56]	train-error:0.004712	test-error:0.004866	train-MCC:0.555415	test-MCC:0.455407
# [57]	train-error:0.004705	test-error:0.004857	train-MCC:0.558931	test-MCC:0.453065
# [58]	train-error:0.004693	test-error:0.004853	train-MCC:0.56177	test-MCC:0.454737
# [59]	train-error:0.004685	test-error:0.004845	train-MCC:0.563742	test-MCC:0.453908
# [60]	train-error:0.004673	test-error:0.004845	train-MCC:0.564722	test-MCC:0.455228
# [61]	train-error:0.004658	test-error:0.004853	train-MCC:0.566957	test-MCC:0.456519
# [62]	train-error:0.004646	test-error:0.004849	train-MCC:0.571512	test-MCC:0.455931
# [63]	train-error:0.004635	test-error:0.004849	train-MCC:0.573437	test-MCC:0.456519
# [64]	train-error:0.004627	test-error:0.004845	train-MCC:0.577341	test-MCC:0.459311
# [65]	train-error:0.004616	test-error:0.004841	train-MCC:0.58284	test-MCC:0.459731
# [66]	train-error:0.004605	test-error:0.004836	train-MCC:0.583661	test-MCC:0.458482
# [67]	train-error:0.004598	test-error:0.004828	train-MCC:0.584832	test-MCC:0.459474
# [68]	train-error:0.00459	test-error:0.004824	train-MCC:0.588456	test-MCC:0.459474
# [69]	train-error:0.004582	test-error:0.004815	train-MCC:0.589926	test-MCC:0.458719
# [70]	train-error:0.004571	test-error:0.004798	train-MCC:0.592061	test-MCC:0.460061
# [71]	train-error:0.004567	test-error:0.004798	train-MCC:0.596011	test-MCC:0.460115
# [72]	train-error:0.004557	test-error:0.004794	train-MCC:0.598433	test-MCC:0.461558
# [73]	train-error:0.004545	test-error:0.00479	train-MCC:0.601003	test-MCC:0.460327
# [74]	train-error:0.004538	test-error:0.004777	train-MCC:0.60283	test-MCC:0.461518
# [75]	train-error:0.00453	test-error:0.004777	train-MCC:0.605824	test-MCC:0.461224
# [76]	train-error:0.004525	test-error:0.004765	train-MCC:0.607838	test-MCC:0.461491
# [77]	train-error:0.004521	test-error:0.004756	train-MCC:0.610705	test-MCC:0.461258
# ...
# [8]	train-error:0.005811	test-error:0.005812	train-MCC:0.410175	test-MCC:0.407871
# [9]	train-error:0.005811	test-error:0.005812	train-MCC:0.416993	test-MCC:0.408148
# [10]	train-error:0.005811	test-error:0.005812	train-MCC:0.423625	test-MCC:0.412839
# [11]	train-error:0.005811	test-error:0.005812	train-MCC:0.429553	test-MCC:0.417075
# [12]	train-error:0.005811	test-error:0.005812	train-MCC:0.436314	test-MCC:0.421037
# [13]	train-error:0.005811	test-error:0.005812	train-MCC:0.440991	test-MCC:0.422226
# [14]	train-error:0.005811	test-error:0.005812	train-MCC:0.446548	test-MCC:0.427094
# [15]	train-error:0.005811	test-error:0.005812	train-MCC:0.451988	test-MCC:0.427482
# [16]	train-error:0.005808	test-error:0.005799	train-MCC:0.455891	test-MCC:0.42806
# [17]	train-error:0.005806	test-error:0.005799	train-MCC:0.461766	test-MCC:0.434143
# [18]	train-error:0.005805	test-error:0.005799	train-MCC:0.466005	test-MCC:0.436292
# [19]	train-error:0.005785	test-error:0.005782	train-MCC:0.471371	test-MCC:0.440496
# [20]	train-error:0.005747	test-error:0.005749	train-MCC:0.474402	test-MCC:0.442179
# [21]	train-error:0.00569	test-error:0.005711	train-MCC:0.477569	test-MCC:0.44369
# [22]	train-error:0.005595	test-error:0.005609	train-MCC:0.481244	test-MCC:0.445263
# [23]	train-error:0.00553	test-error:0.005563	train-MCC:0.484284	test-MCC:0.444972
# [24]	train-error:0.005482	test-error:0.005516	train-MCC:0.486183	test-MCC:0.44493
# [25]	train-error:0.005451	test-error:0.005474	train-MCC:0.487356	test-MCC:0.446563
# [26]	train-error:0.005421	test-error:0.005436	train-MCC:0.491048	test-MCC:0.4467
# [27]	train-error:0.005382	test-error:0.005407	train-MCC:0.492432	test-MCC:0.449047
# [28]	train-error:0.005334	test-error:0.005356	train-MCC:0.494201	test-MCC:0.449289
# [29]	train-error:0.00528	test-error:0.005305	train-MCC:0.494754	test-MCC:0.451336
# [30]	train-error:0.005228	test-error:0.005263	train-MCC:0.49789	test-MCC:0.450464
# [31]	train-error:0.005185	test-error:0.005229	train-MCC:0.500286	test-MCC:0.45064
# [32]	train-error:0.005149	test-error:0.005195	train-MCC:0.502051	test-MCC:0.450828
# [33]	train-error:0.005113	test-error:0.005157	train-MCC:0.503239	test-MCC:0.451007
# [34]	train-error:0.005064	test-error:0.005136	train-MCC:0.505016	test-MCC:0.452041
# [35]	train-error:0.005046	test-error:0.005132	train-MCC:0.507762	test-MCC:0.452224
# [36]	train-error:0.005025	test-error:0.005102	train-MCC:0.508922	test-MCC:0.451334
# [37]	train-error:0.004998	test-error:0.005073	train-MCC:0.510177	test-MCC:0.452408
# [38]	train-error:0.004959	test-error:0.005048	train-MCC:0.511722	test-MCC:0.451868
# [39]	train-error:0.00494	test-error:0.005026	train-MCC:0.513404	test-MCC:0.452917
# [40]	train-error:0.004913	test-error:0.005018	train-MCC:0.515235	test-MCC:0.453444
# [41]	train-error:0.004894	test-error:0.004997	train-MCC:0.516513	test-MCC:0.453635
# [42]	train-error:0.004876	test-error:0.004993	train-MCC:0.520199	test-MCC:0.454913
# [43]	train-error:0.00486	test-error:0.004984	train-MCC:0.522161	test-MCC:0.454741
# [44]	train-error:0.004849	test-error:0.00495	train-MCC:0.525093	test-MCC:0.454456
# [45]	train-error:0.004831	test-error:0.004933	train-MCC:0.526988	test-MCC:0.454164
# [46]	train-error:0.004816	test-error:0.004925	train-MCC:0.532727	test-MCC:0.455691
# [47]	train-error:0.004794	test-error:0.004912	train-MCC:0.532929	test-MCC:0.456742
# [48]	train-error:0.004771	test-error:0.004904	train-MCC:0.534974	test-MCC:0.4569
# [49]	train-error:0.004756	test-error:0.004887	train-MCC:0.538414	test-MCC:0.457278
# [50]	train-error:0.004734	test-error:0.004883	train-MCC:0.543625	test-MCC:0.458418
# [51]	train-error:0.004721	test-error:0.004857	train-MCC:0.544778	test-MCC:0.457497
# [52]	train-error:0.004708	test-error:0.004845	train-MCC:0.547752	test-MCC:0.458716
# [53]	train-error:0.004692	test-error:0.004849	train-MCC:0.550482	test-MCC:0.459418
# [54]	train-error:0.004675	test-error:0.004836	train-MCC:0.55347	test-MCC:0.458804
# [55]	train-error:0.004664	test-error:0.004824	train-MCC:0.553906	test-MCC:0.459386
# [56]	train-error:0.00465	test-error:0.004815	train-MCC:0.557266	test-MCC:0.460347
# [57]	train-error:0.004639	test-error:0.004798	train-MCC:0.559704	test-MCC:0.460347
# [58]	train-error:0.004627	test-error:0.004794	train-MCC:0.56119	test-MCC:0.460618
# [59]	train-error:0.004615	test-error:0.004781	train-MCC:0.562193	test-MCC:0.459583
# [60]	train-error:0.004606	test-error:0.004773	train-MCC:0.564259	test-MCC:0.460159
# [61]	train-error:0.004601	test-error:0.004765	train-MCC:0.565779	test-MCC:0.460597
# [62]	train-error:0.004587	test-error:0.004765	train-MCC:0.568747	test-MCC:0.459565
# [63]	train-error:0.004581	test-error:0.004765	train-MCC:0.572449	test-MCC:0.459215
# [64]	train-error:0.00457	test-error:0.00476	train-MCC:0.575896	test-MCC:0.459782
# [65]	train-error:0.004565	test-error:0.004752	train-MCC:0.577401	test-MCC:0.461148
# [66]	train-error:0.004557	test-error:0.004743	train-MCC:0.582508	test-MCC:0.460091
# [67]	train-error:0.004554	test-error:0.004735	train-MCC:0.584024	test-MCC:0.460619
# [68]	train-error:0.004546	test-error:0.004731	train-MCC:0.586687	test-MCC:0.460619
# [69]	train-error:0.004544	test-error:0.004718	train-MCC:0.588539	test-MCC:0.461378
# [70]	train-error:0.004548	test-error:0.004718	train-MCC:0.589626	test-MCC:0.46157
# [71]	train-error:0.004538	test-error:0.004714	train-MCC:0.592251	test-MCC:0.461363
# [72]	train-error:0.00453	test-error:0.004705	train-MCC:0.595042	test-MCC:0.460619
# [73]	train-error:0.004528	test-error:0.004697	train-MCC:0.597237	test-MCC:0.459911
# [74]	train-error:0.004523	test-error:0.004688	train-MCC:0.598549	test-MCC:0.460127
# [75]	train-error:0.004511	test-error:0.004693	train-MCC:0.60098	test-MCC:0.460344
# [76]	train-error:0.004503	test-error:0.004688	train-MCC:0.602773	test-MCC:0.460344
# [77]	train-error:0.004502	test-error:0.00468	train-MCC:0.603863	test-MCC:0.458814
# [78]	train-error:0.004496	test-error:0.004688	train-MCC:0.607076	test-MCC:0.459034
# [79]	train-error:0.004488	test-error:0.004688	train-MCC:0.608925	test-MCC:0.459397
# [80]	train-error:0.004486	test-error:0.004684	train-MCC:0.611371	test-MCC:0.458864
# [81]	train-error:0.00448	test-error:0.004684	train-MCC:0.611558	test-MCC:0.458334
# [82]	train-error:0.004476	test-error:0.00468	train-MCC:0.614284	test-MCC:0.457776
# [83]	train-error:0.004473	test-error:0.004676	train-MCC:0.617359	test-MCC:0.459013
# [84]	train-error:0.00446	test-error:0.004663	train-MCC:0.621191	test-MCC:0.459331
# [85]	train-error:0.004456	test-error:0.004663	train-MCC:0.623807	test-MCC:0.459246
# [86]	train-error:0.004447	test-error:0.004663	train-MCC:0.626436	test-MCC:0.45865
# [87]	train-error:0.004436	test-error:0.004659	train-MCC:0.628135	test-MCC:0.459605
# [88]	train-error:0.00443	test-error:0.004659	train-MCC:0.631035	test-MCC:0.459424
# [89]	train-error:0.004423	test-error:0.004659	train-MCC:0.633268	test-MCC:0.459424
# [90]	train-error:0.004414	test-error:0.004659	train-MCC:0.637185	test-MCC:0.45865
# [91]	train-error:0.004407	test-error:0.004659	train-MCC:0.63896	test-MCC:0.45919
# [92]	train-error:0.004404	test-error:0.00465	train-MCC:0.639145	test-MCC:0.4592
# [93]	train-error:0.004399	test-error:0.004655	train-MCC:0.639851	test-MCC:0.458813
# [94]	train-error:0.004392	test-error:0.004655	train-MCC:0.642399	test-MCC:0.458813
# [95]	train-error:0.004386	test-error:0.004655	train-MCC:0.644071	test-MCC:0.459164
# [96]	train-error:0.004383	test-error:0.00465	train-MCC:0.646758	test-MCC:0.459
# [97]	train-error:0.004374	test-error:0.004655	train-MCC:0.649116	test-MCC:0.458895
# [98]	train-error:0.004372	test-error:0.00465	train-MCC:0.65091	test-MCC:0.459518
# [99]	train-error:0.004371	test-error:0.00465	train-MCC:0.652165	test-MCC:0.459518
# Repeat 2, split 0, test MCC = 0.460, running time = 22.574 min
# [0]	train-error:0.005811	test-error:0.005812	train-MCC:0.259939	test-MCC:0.257936
# [1]	train-error:0.005811	test-error:0.005812	train-MCC:0.324576	test-MCC:0.32484
# [2]	train-error:0.005811	test-error:0.005812	train-MCC:0.366088	test-MCC:0.365885
# [3]	train-error:0.005811	test-error:0.005812	train-MCC:0.375176	test-MCC:0.379036
# [4]	train-error:0.005811	test-error:0.005812	train-MCC:0.390402	test-MCC:0.380717
# [5]	train-error:0.005811	test-error:0.005812	train-MCC:0.39323	test-MCC:0.379587
# [6]	train-error:0.005811	test-error:0.005812	train-MCC:0.410503	test-MCC:0.379807
# [7]	train-error:0.005811	test-error:0.005812	train-MCC:0.415611	test-MCC:0.381574
# [8]	train-error:0.005811	test-error:0.005812	train-MCC:0.420572	test-MCC:0.383093
# [9]	train-error:0.005811	test-error:0.005812	train-MCC:0.426616	test-MCC:0.3852
# [10]	train-error:0.005811	test-error:0.005812	train-MCC:0.433982	test-MCC:0.385819
# [11]	train-error:0.00581	test-error:0.005812	train-MCC:0.444882	test-MCC:0.391286
# [12]	train-error:0.00581	test-error:0.005812	train-MCC:0.449679	test-MCC:0.394016
# [13]	train-error:0.00581	test-error:0.005812	train-MCC:0.453412	test-MCC:0.397664
# [14]	train-error:0.005808	test-error:0.005812	train-MCC:0.455461	test-MCC:0.398604
# [15]	train-error:0.005807	test-error:0.005808	train-MCC:0.458842	test-MCC:0.39991
# [16]	train-error:0.005806	test-error:0.005808	train-MCC:0.462938	test-MCC:0.401503
# [17]	train-error:0.005803	test-error:0.005808	train-MCC:0.46672	test-MCC:0.401101
# [18]	train-error:0.005788	test-error:0.005795	train-MCC:0.47084	test-MCC:0.404721
# [19]	train-error:0.005761	test-error:0.005778	train-MCC:0.471558	test-MCC:0.406567
# [20]	train-error:0.005722	test-error:0.005728	train-MCC:0.477681	test-MCC:0.410673
# [21]	train-error:0.00568	test-error:0.005702	train-MCC:0.481946	test-MCC:0.40978
# [22]	train-error:0.00563	test-error:0.005656	train-MCC:0.484069	test-MCC:0.411795
# [23]	train-error:0.005549	test-error:0.005592	train-MCC:0.487992	test-MCC:0.415038
# [24]	train-error:0.005472	test-error:0.005542	train-MCC:0.489699	test-MCC:0.417181
# [25]	train-error:0.0054	test-error:0.005461	train-MCC:0.492839	test-MCC:0.420198
# [26]	train-error:0.005325	test-error:0.005407	train-MCC:0.495181	test-MCC:0.422467
# [27]	train-error:0.005263	test-error:0.005335	train-MCC:0.495765	test-MCC:0.426196
# [28]	train-error:0.005212	test-error:0.005318	train-MCC:0.498985	test-MCC:0.42595
# [29]	train-error:0.005188	test-error:0.005305	train-MCC:0.500957	test-MCC:0.427755
# [30]	train-error:0.005155	test-error:0.005246	train-MCC:0.503236	test-MCC:0.427468
# [31]	train-error:0.005127	test-error:0.005212	train-MCC:0.50468	test-MCC:0.431386
# [32]	train-error:0.005099	test-error:0.005195	train-MCC:0.505845	test-MCC:0.431415
# [33]	train-error:0.005074	test-error:0.00517	train-MCC:0.507729	test-MCC:0.432775
# [34]	train-error:0.005049	test-error:0.005145	train-MCC:0.509421	test-MCC:0.433321
# [35]	train-error:0.005023	test-error:0.005128	train-MCC:0.511922	test-MCC:0.433823
# [36]	train-error:0.005006	test-error:0.005111	train-MCC:0.514562	test-MCC:0.435839
# [37]	train-error:0.004985	test-error:0.005086	train-MCC:0.516095	test-MCC:0.435115
# [38]	train-error:0.004961	test-error:0.005086	train-MCC:0.517967	test-MCC:0.439523
# [39]	train-error:0.004945	test-error:0.005077	train-MCC:0.518819	test-MCC:0.439365
# [40]	train-error:0.004929	test-error:0.00506	train-MCC:0.519288	test-MCC:0.439239
# [41]	train-error:0.004907	test-error:0.005048	train-MCC:0.521534	test-MCC:0.439838
# [42]	train-error:0.004891	test-error:0.005039	train-MCC:0.524297	test-MCC:0.439589
# [43]	train-error:0.004873	test-error:0.005035	train-MCC:0.527106	test-MCC:0.44072
# [44]	train-error:0.004859	test-error:0.005026	train-MCC:0.529922	test-MCC:0.44213
# [45]	train-error:0.004838	test-error:0.005018	train-MCC:0.530698	test-MCC:0.440899
# [46]	train-error:0.004819	test-error:0.00501	train-MCC:0.532888	test-MCC:0.442655
# [47]	train-error:0.004807	test-error:0.004988	train-MCC:0.534161	test-MCC:0.442882
# [48]	train-error:0.004778	test-error:0.004971	train-MCC:0.534453	test-MCC:0.444019
# [49]	train-error:0.00476	test-error:0.004967	train-MCC:0.535301	test-MCC:0.443309
# [50]	train-error:0.00475	test-error:0.00495	train-MCC:0.536953	test-MCC:0.443477
# [51]	train-error:0.004735	test-error:0.004946	train-MCC:0.539072	test-MCC:0.445396
# [52]	train-error:0.004719	test-error:0.004929	train-MCC:0.539281	test-MCC:0.444917
# [53]	train-error:0.004709	test-error:0.004912	train-MCC:0.542257	test-MCC:0.445151
# [54]	train-error:0.00469	test-error:0.004904	train-MCC:0.546591	test-MCC:0.444514
# [55]	train-error:0.004675	test-error:0.0049	train-MCC:0.546425	test-MCC:0.444829
# [56]	train-error:0.004657	test-error:0.004887	train-MCC:0.549699	test-MCC:0.444156
# [57]	train-error:0.004639	test-error:0.00487	train-MCC:0.553804	test-MCC:0.443572
# [58]	train-error:0.004622	test-error:0.004866	train-MCC:0.556686	test-MCC:0.444242
# [59]	train-error:0.004608	test-error:0.00487	train-MCC:0.558028	test-MCC:0.443939
# [60]	train-error:0.004597	test-error:0.004866	train-MCC:0.56033	test-MCC:0.445164
# [61]	train-error:0.004587	test-error:0.004857	train-MCC:0.5617	test-MCC:0.445315
# [62]	train-error:0.00458	test-error:0.004857	train-MCC:0.563807	test-MCC:0.446107
# [63]	train-error:0.004559	test-error:0.004862	train-MCC:0.565796	test-MCC:0.44669
# [64]	train-error:0.004548	test-error:0.004849	train-MCC:0.568428	test-MCC:0.448066
# [65]	train-error:0.004536	test-error:0.004845	train-MCC:0.572028	test-MCC:0.447108
# [66]	train-error:0.004528	test-error:0.004832	train-MCC:0.574359	test-MCC:0.446898
# [67]	train-error:0.004525	test-error:0.004819	train-MCC:0.576492	test-MCC:0.446671
# [68]	train-error:0.004521	test-error:0.004803	train-MCC:0.578031	test-MCC:0.446961
# [69]	train-error:0.004515	test-error:0.004803	train-MCC:0.579213	test-MCC:0.448453
# [70]	train-error:0.004507	test-error:0.00479	train-MCC:0.581129	test-MCC:0.448453
# [71]	train-error:0.004498	test-error:0.004794	train-MCC:0.583377	test-MCC:0.447863
# [72]	train-error:0.004493	test-error:0.004781	train-MCC:0.585569	test-MCC:0.447863
# [73]	train-error:0.004485	test-error:0.004781	train-MCC:0.588677	test-MCC:0.447276
# [74]	train-error:0.00448	test-error:0.004773	train-MCC:0.590777	test-MCC:0.448127
# [75]	train-error:0.004474	test-error:0.004786	train-MCC:0.59334	test-MCC:0.447276
# [76]	train-error:0.004468	test-error:0.004777	train-MCC:0.59596	test-MCC:0.446172
# [77]	train-error:0.00446	test-error:0.004777	train-MCC:0.60031	test-MCC:0.447108
# [78]	train-error:0.004455	test-error:0.004781	train-MCC:0.602156	test-MCC:0.446961
# [79]	train-error:0.004446	test-error:0.004777	train-MCC:0.604554	test-MCC:0.44732
# [80]	train-error:0.004433	test-error:0.004773	train-MCC:0.606503	test-MCC:0.44732
# [81]	train-error:0.00443	test-error:0.004773	train-MCC:0.609556	test-MCC:0.44732
# [82]	train-error:0.004417	test-error:0.004769	train-MCC:0.611646	test-MCC:0.447749
# [83]	train-error:0.004413	test-error:0.004773	train-MCC:0.613687	test-MCC:0.448406
# [84]	train-error:0.00441	test-error:0.004769	train-MCC:0.614836	test-MCC:0.449412
# [85]	train-error:0.004404	test-error:0.004765	train-MCC:0.617539	test-MCC:0.449973
# [86]	train-error:0.004399	test-error:0.004769	train-MCC:0.619722	test-MCC:0.449973
# [87]	train-error:0.004391	test-error:0.004769	train-MCC:0.622091	test-MCC:0.449754
# [88]	train-error:0.004392	test-error:0.004769	train-MCC:0.626359	test-MCC:0.449973
# [89]	train-error:0.004386	test-error:0.00476	train-MCC:0.627655	test-MCC:0.449892
# [90]	train-error:0.004385	test-error:0.00476	train-MCC:0.62934	test-MCC:0.448629
# [91]	train-error:0.004385	test-error:0.00476	train-MCC:0.632364	test-MCC:0.448186
# [92]	train-error:0.004376	test-error:0.00476	train-MCC:0.634759	test-MCC:0.449537
# [93]	train-error:0.004374	test-error:0.00476	train-MCC:0.638057	test-MCC:0.449754
# [94]	train-error:0.00437	test-error:0.00476	train-MCC:0.638667	test-MCC:0.450105
# [95]	train-error:0.004361	test-error:0.004752	train-MCC:0.641794	test-MCC:0.44919
# [96]	train-error:0.004358	test-error:0.004752	train-MCC:0.642889	test-MCC:0.449537
# [97]	train-error:0.004353	test-error:0.004748	train-MCC:0.645986	test-MCC:0.449537
# [98]	train-error:0.004348	test-error:0.004752	train-MCC:0.649576	test-MCC:0.448629
# [99]	train-error:0.004344	test-error:0.004748	train-MCC:0.650673	test-MCC:0.448523
# Repeat 2, split 1, test MCC = 0.449, running time = 19.730 min

# %%
cv_train_mean = cv_results['train'].mean(axis=1)
cv_train_std = cv_results['train'].std(axis=1)
cv_test_mean = cv_results['test'].mean(axis=1)
cv_test_std = cv_results['test'].std(axis=1)

# %%
plt.figure(figsize=(14, 7))
plt.plot(np.arange(len(cv_train_mean)), cv_train_mean)
plt.fill_between(np.arange(len(cv_train_mean)), cv_train_mean-cv_train_std, cv_train_mean+cv_train_std, alpha=0.5)
plt.plot(np.arange(len(cv_train_mean)), cv_test_mean)
plt.fill_between(np.arange(len(cv_test_mean)), cv_test_mean-cv_test_std, cv_test_mean+cv_test_std, alpha=0.5)
plt.legend(['train', 'test'])

# %%
# Train the model
dtrain = xgb.DMatrix(x_train, label=y_train)
params['seed'] = 28537894
clf = xgb.train(params, dtrain, num_boost_round=60,
               feval=mcc_eval, evals=[(dtrain, 'train')])

y_train_pred = clf.predict(dtrain)

# Find best threshold 
thresholds = np.linspace(0.01, 0.99, 400)
mcc = np.array([matthews_corrcoef(y_train, y_train_pred>thr) for thr in thresholds])
plt.plot(thresholds, mcc)
best_threshold = thresholds[mcc.argmax()]

print('Optimal MCC = {:.3f}'.format(mcc.max()))
print('Optimal threshold = {:.3f}'.format(best_threshold))

# %% [markdown]
# ### Predict on test data

# %%
dtest = xgb.DMatrix(x_test)
y_test_pred = clf.predict(dtest)
y_test_pred_int = (y_test_pred>best_threshold).astype(int)

sub = pd.read_csv("../../data/sample_submission.csv.zip", index_col=0)
sub["Response"] = y_test_pred_int
sub.to_csv("15-benchmark_7_submission_1.csv.gz", compression="gzip")

# %%
cv_test_mean[60]+cv_test_std[60]

cv_test_mean[60]-cv_test_std[60]

cv_test_mean[79]

cv_test_std[60]
